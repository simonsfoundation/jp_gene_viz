# %% [markdown]
# # Stand alone heatmap
#
# The interaction below loads and initializes a stand alone
# heatmap widget for exploring gene expression data.  The widget supports
# selection of genes and conditions using space separated lists of
# names or "glob" patterns.
#
# For example to select all `th0` conditions add `th0*` in the conditions
# text area and click the conditions button.
#
# To select `nsf`, `nme4`, and `nudt4` genes add `nsf nme4 nudt4` in the
# genes text area and click the genes button.

# %%
from jp_gene_viz import dExpression

# %%
dExpression.load_javascript_support()

# %%
tsv = "/Users/ndeveaux/Dev/th17_jj_gsea/out/th17_jj_deseq_output_0805/pTh17jj_RNAseq_th17P_96h_aKo_v_th17P_96h.txt"
E = dExpression.display_heat_map(tsv, show=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-a4df13d00a31> in <module>()
#       1 tsv = "/Users/ndeveaux/Dev/th17_jj_gsea/out/th17_jj_deseq_output_0805/pTh17jj_RNAseq_th17P_96h_v_th17N_96h.txt"
# ----> 2 E = dExpression.display_heat_map(tsv, show=True)
#
# //anaconda/lib/python2.7/site-packages/jp_gene_viz-0.0.1-py2.7.egg/jp_gene_viz/dExpression.pyc in display_heat_map(filename, dexpr, side_length, show)
#     247     from jp_gene_viz import getData
#     248     H = HMap.HeatMap()
# --> 249     (r, c, d) = getData.read_tsv(filename)
#     250     H.set_data(r, c, d)
#     251     if dexpr is None:
#
# //anaconda/lib/python2.7/site-packages/jp_gene_viz-0.0.1-py2.7.egg/jp_gene_viz/getData.pyc in read_tsv(fn)
#      58         rowname = data[0]
#      59         valuestr = data[1:]
# ---> 60         values = map(float, valuestr)
#      61         assert len(values) == len(column_names), repr(
#      62             (len(values), len(column_names)))
#
# ValueError: could not convert string to float: NA

# %%
E.match_text.value = "th0*"
E.match_click()
E.genes_text.value = "nsf nme4 nudt4"
E.genes_click()
E.title_html.value = "experiment th0 values for ssf, nme4, and nudt4"
E.transform_dropdown.value = dExpression.LOG2_TRANSFORM
