# %% [markdown]
# # js_proxy
#
# The `js_proxy` widget implementation is meant to be the widget to end all widgets (sort of).
#
# To implement a Jupyter/Python/javascript widget you generally need a Python side implementation
# for the widget and a javascript side for the widget which match up to eachother.  In general to
# add more features to the widget you need to modify both sides in matching ways.
#
# For high performance widgets that is the right way to go because it allows you to maintain
# complex state on the javascript side and handle high performance callbacks and other operations
# without requiring communication between the python side and the javascript side (which may
# be very important especially if the two sides are running on different computers over a network
# connection).
#
# However for widgets where the performance considerations are not so critical the widget framework
# can be cumbersome.  For example if I want to have jQueryUI dialog pop up I need to execute something
# along the lines of the following javascript:
#
# `$(DomElement).html("Hello from jQueryUI").dialog()`
#
# Using the `js_proxy` mechanism you can do something like this that looks similar:

# %%
# First import needed modules and javascript support
from jp_gene_viz import js_proxy
# this loads the proxy widget javascript "view" implementation
js_proxy.load_javascript_support()
from IPython.display import display

# %%
# Then create a "proxy widget" for the jQueryUI dialog.
d = js_proxy.ProxyWidget()

# Construct a command to make the widget into a jQueryUI dialog.
command = d.element().html('<b id="my_dialog">Hello from jQueryUI</b>').dialog()

# Send the command to the widget view (javascript side).
d.send(command)

# Display the widget, which causes the command to also execute.
display(d)

# %% [markdown]
# If you execute the previous cell you should see a jQueryUI dialog pop up.
# Click the close button to make the dialog invisible.
#
# The following cell should make it appear again.

# %%
make_visible = d.element().dialog()
d.send(make_visible)
# Out:
# [1, [['method', ['element'], 'dialog']], 1]

# %% [markdown]
# The above illustrates that commands can be sent to the widget after it has been displayed.
#
# [It is important to note that no commands are executed before a widget is displayed, so
# until the widget is displayed you should only call `send` or `send_commands` (which sends
# multiple commands in one go) once, because only the commands from the last call will get
# executed.  After the widget is displayed multiple calls are allowed.]
#
# The proxy mechanism works by capturing interactions on the Python side, encoding those
# interactions as a JSON object, transferring the JSON object to the Javascript side, and then
# interpreting the JSON object as a sequence of actions on the Javascript side.
#
# Results from the Javascript actions are also passed back to the python side in the `results`
# trait of the Python side widget object:

# %%
d.results  # The results from the last command are not particularly meaningful.
# Out:
# [1, [{u'jquery': u'2.0.3', u'length': 1, u'selector': u''}]]

# %% [markdown]
# # Getting values from Javascript
#
# The communication between the Python widget object and the Javascript view is asyncronous.
# To do something with the results generated by a javascript interaction you may associate a
# callback to process the results when they arrive.

# %%
# We want to put the html from the widget in this list
save_list = []

def save_command_result(result):
    "this is the callback we want to execute when the results arrive"
    #print (result)
    save_list.append(result)

# This "action" gets the html content of the widget.
get_html = d.element().html()

# Send the action to the javascript side for async execution.
d.send(get_html, results_callback=save_command_result)

# If we look at save_list now, it will probably be empty because the
# javascript side has probably not responded yet.
save_list
# Out:
# []

# %%
# But later we should see the HTML saved in the list.
save_list
# Out:
# [[u'<b id="my_dialog">Hello from jQueryUI</b>']]

# %% [markdown]
# The result returned to the callback shown above
# is the HTML for the widget inside a list.
# The result is in a list because in general the callback mechanism
# permits results for command sequences in addition to results of
# individual commands.
#
#
# # Command result translation depth level
#
# Results of commands are translated to JSON compatible values using recursive traversal
# of Javascript arrays and objects truncated to a depth which defaults to 1.  To traverse
# deeper into the structures you may provide a `level` parameter for `send` or `send_commands`
# which allows recursive depth up to 5.  To prevent recursion into complex values
# set the `level` to `0`.
#
# Below we get a fairly large data structure from the HTML Document Object Model (DOM) tree
# by traversing the DOM element for the widget to 2 levels deep.

# %%
# get the DOM element associated with the widget from inside the JQuery container.
get_dom_element = d.element().get(0)
d.send(get_dom_element, results_callback=save_command_result, level=2)
# Out:
# [3, [['method', ['element'], 'get', 0]], 2]

# %%
# examine the JSON representation for the element sent to the callback (up to 2 levels deep)
save_list[-1]
# Out:
# [{u'ATTRIBUTE_NODE': 2,
#   u'CDATA_SECTION_NODE': 4,
#   u'COMMENT_NODE': 8,
#   u'DOCUMENT_FRAGMENT_NODE': 11,
#   u'DOCUMENT_NODE': 9,
#   u'DOCUMENT_POSITION_CONTAINED_BY': 16,
#   u'DOCUMENT_POSITION_CONTAINS': 8,
#   u'DOCUMENT_POSITION_DISCONNECTED': 1,
#   u'DOCUMENT_POSITION_FOLLOWING': 4,
#   u'DOCUMENT_POSITION_IMPLEMENTATION_SPECIFIC': 32,
#   u'DOCUMENT_POSITION_PRECEDING': 2,
#   u'DOCUMENT_TYPE_NODE': 10,
#   u'ELEMENT_NODE': 1,
#   u'ENTITY_NODE': 6,
#   u'ENTITY_REFERENCE_NODE': 5,
#   u'NOTATION_NODE': 12,
#   u'PROCESSING_INSTRUCTION_NODE': 7,
#   u'TEXT_NODE': 3,
#   u'accessKey': u'',
#   u'addEventListener': {},
#   u'align': u'',
#   u'animate': {},
#   u'appendChild': {},
#   u'attributes': {u'length': 3},
#   u'baseURI': u'http://localhost:8888/notebooks/repos/jp_gene_viz/examples/js_proxy%20example.ipynb#',
#   u'blur': {},
#   u'childElementCount': 1,
#   u'childNodes': {u'length': 1},
#   u'children': {u'length': 1},
#   u'classList': {u'0': u'ui-dialog-content',
#    u'1': u'ui-widget-content',
#    u'length': 2},
#   u'className': u'ui-dialog-content ui-widget-content',
#   u'click': {},
#   u'clientHeight': 0,
#   u'clientLeft': 0,
#   u'clientTop': 0,
#   u'clientWidth': 0,
#   u'cloneNode': {},
#   u'closest': {},
#   u'compareDocumentPosition': {},
#   u'contains': {},
#   u'contentEditable': u'inherit',
#   u'createShadowRoot': {},
#   u'dataset': {},
#   u'dir': u'',
#   u'dispatchEvent': {},
#   u'draggable': False,
#   u'firstChild': {u'ATTRIBUTE_NODE': 2,
#    u'CDATA_SECTION_NODE': 4,
#    u'COMMENT_NODE': 8,
#    u'DOCUMENT_FRAGMENT_NODE': 11,
#    u'DOCUMENT_NODE': 9,
#    u'DOCUMENT_POSITION_CONTAINED_BY': 16,
#    u'DOCUMENT_POSITION_CONTAINS': 8,
#    u'DOCUMENT_POSITION_DISCONNECTED': 1,
#    u'DOCUMENT_POSITION_FOLLOWING': 4,
#    u'DOCUMENT_POSITION_IMPLEMENTATION_SPECIFIC': 32,
#    u'DOCUMENT_POSITION_PRECEDING': 2,
#    u'DOCUMENT_TYPE_NODE': 10,
#    u'ELEMENT_NODE': 1,
#    u'ENTITY_NODE': 6,
#    u'ENTITY_REFERENCE_NODE': 5,
#    u'NOTATION_NODE': 12,
#    u'PROCESSING_INSTRUCTION_NODE': 7,
#    u'TEXT_NODE': 3,
#    u'accessKey': u'',
#    u'baseURI': u'http://localhost:8888/notebooks/repos/jp_gene_viz/examples/js_proxy%20example.ipynb#',
#    u'childElementCount': 0,
#    u'className': u'',
#    u'clientHeight': 0,
#    u'clientLeft': 0,
#    u'clientTop': 0,
#    u'clientWidth': 0,
#    u'contentEditable': u'inherit',
#    u'dir': u'',
#    u'draggable': False,
#    u'hidden': False,
#    u'id': u'my_dialog',
#    u'innerHTML': u'Hello from jQueryUI',
#    u'innerText': u'Hello from jQueryUI',
#    u'isContentEditable': False,
#    u'lang': u'',
#    u'localName': u'b',
#    u'namespaceURI': u'http://www.w3.org/1999/xhtml',
#    u'nodeName': u'B',
#    u'nodeType': 1,
#    u'offsetHeight': 0,
#    u'offsetLeft': 0,
#    u'offsetTop': 0,
#    u'offsetWidth': 0,
#    u'outerHTML': u'<b id="my_dialog">Hello from jQueryUI</b>',
#    u'outerText': u'Hello from jQueryUI',
#    u'scrollHeight': 0,
#    u'scrollLeft': 0,
#    u'scrollTop': 0,
#    u'scrollWidth': 0,
#    u'spellcheck': True,
#    u'tabIndex': -1,
#    u'tagName': u'B',
#    u'textContent': u'Hello from jQueryUI',
#    u'title': u'',
#    u'translate': True,
#    u'webkitdropzone': u''},
#   u'firstElementChild': {u'ATTRIBUTE_NODE': 2,
#    u'CDATA_SECTION_NODE': 4,
#    u'COMMENT_NODE': 8,
#    u'DOCUMENT_FRAGMENT_NODE': 11,
#    u'DOCUMENT_NODE': 9,
#    u'DOCUMENT_POSITION_CONTAINED_BY': 16,
#    u'DOCUMENT_POSITION_CONTAINS': 8,
#    u'DOCUMENT_POSITION_DISCONNECTED': 1,
#    u'DOCUMENT_POSITION_FOLLOWING': 4,
#    u'DOCUMENT_POSITION_IMPLEMENTATION_SPECIFIC': 32,
#    u'DOCUMENT_POSITION_PRECEDING': 2,
#    u'DOCUMENT_TYPE_NODE': 10,
#    u'ELEMENT_NODE': 1,
#    u'ENTITY_NODE': 6,
#    u'ENTITY_REFERENCE_NODE': 5,
#    u'NOTATION_NODE': 12,
#    u'PROCESSING_INSTRUCTION_NODE': 7,
#    u'TEXT_NODE': 3,
#    u'accessKey': u'',
#    u'baseURI': u'http://localhost:8888/notebooks/repos/jp_gene_viz/examples/js_proxy%20example.ipynb#',
#    u'childElementCount': 0,
#    u'className': u'',
#    u'clientHeight': 0,
#    u'clientLeft': 0,
#    u'clientTop': 0,
#    u'clientWidth': 0,
#    u'contentEditable': u'inherit',
#    u'dir': u'',
#    u'draggable': False,
#    u'hidden': False,
#    u'id': u'my_dialog',
#    u'innerHTML': u'Hello from jQueryUI',
#    u'innerText': u'Hello from jQueryUI',
#    u'isContentEditable': False,
#    u'lang': u'',
#    u'localName': u'b',
#    u'namespaceURI': u'http://www.w3.org/1999/xhtml',
#    u'nodeName': u'B',
#    u'nodeType': 1,
#    u'offsetHeight': 0,
#    u'offsetLeft': 0,
#    u'offsetTop': 0,
#    u'offsetWidth': 0,
#    u'outerHTML': u'<b id="my_dialog">Hello from jQueryUI</b>',
#    u'outerText': u'Hello from jQueryUI',
#    u'scrollHeight': 0,
#    u'scrollLeft': 0,
#    u'scrollTop': 0,
#    u'scrollWidth': 0,
#    u'spellcheck': True,
#    u'tabIndex': -1,
#    u'tagName': u'B',
#    u'textContent': u'Hello from jQueryUI',
#    u'title': u'',
#    u'translate': True,
#    u'webkitdropzone': u''},
#   u'focus': {},
#   u'getAttribute': {},
#   u'getAttributeNS': {},
#   u'getAttributeNode': {},
#   u'getAttributeNodeNS': {},
#   u'getBoundingClientRect': {},
#   u'getClientRects': {},
#   u'getDestinationInsertionPoints': {},
#   u'getElementsByClassName': {},
#   u'getElementsByTagName': {},
#   u'getElementsByTagNameNS': {},
#   u'hasAttribute': {},
#   u'hasAttributeNS': {},
#   u'hasAttributes': {},
#   u'hasChildNodes': {},
#   u'hidden': False,
#   u'id': u'ui-id-3',
#   u'innerHTML': u'<b id="my_dialog">Hello from jQueryUI</b>',
#   u'innerText': u'Hello from jQueryUI',
#   u'insertAdjacentElement': {},
#   u'insertAdjacentHTML': {},
#   u'insertAdjacentText': {},
#   u'insertBefore': {},
#   u'isContentEditable': False,
#   u'isDefaultNamespace': {},
#   u'isEqualNode': {},
#   u'isSameNode': {},
#   u'lang': u'',
#   u'lastChild': {u'ATTRIBUTE_NODE': 2,
#    u'CDATA_SECTION_NODE': 4,
#    u'COMMENT_NODE': 8,
#    u'DOCUMENT_FRAGMENT_NODE': 11,
#    u'DOCUMENT_NODE': 9,
#    u'DOCUMENT_POSITION_CONTAINED_BY': 16,
#    u'DOCUMENT_POSITION_CONTAINS': 8,
#    u'DOCUMENT_POSITION_DISCONNECTED': 1,
#    u'DOCUMENT_POSITION_FOLLOWING': 4,
#    u'DOCUMENT_POSITION_IMPLEMENTATION_SPECIFIC': 32,
#    u'DOCUMENT_POSITION_PRECEDING': 2,
#    u'DOCUMENT_TYPE_NODE': 10,
#    u'ELEMENT_NODE': 1,
#    u'ENTITY_NODE': 6,
#    u'ENTITY_REFERENCE_NODE': 5,
#    u'NOTATION_NODE': 12,
#    u'PROCESSING_INSTRUCTION_NODE': 7,
#    u'TEXT_NODE': 3,
#    u'accessKey': u'',
#    u'baseURI': u'http://localhost:8888/notebooks/repos/jp_gene_viz/examples/js_proxy%20example.ipynb#',
#    u'childElementCount': 0,
#    u'className': u'',
#    u'clientHeight': 0,
#    u'clientLeft': 0,
#    u'clientTop': 0,
#    u'clientWidth': 0,
#    u'contentEditable': u'inherit',
#    u'dir': u'',
#    u'draggable': False,
#    u'hidden': False,
#    u'id': u'my_dialog',
#    u'innerHTML': u'Hello from jQueryUI',
#    u'innerText': u'Hello from jQueryUI',
#    u'isContentEditable': False,
#    u'lang': u'',
#    u'localName': u'b',
#    u'namespaceURI': u'http://www.w3.org/1999/xhtml',
#    u'nodeName': u'B',
#    u'nodeType': 1,
#    u'offsetHeight': 0,
#    u'offsetLeft': 0,
#    u'offsetTop': 0,
#    u'offsetWidth': 0,
#    u'outerHTML': u'<b id="my_dialog">Hello from jQueryUI</b>',
#    u'outerText': u'Hello from jQueryUI',
#    u'scrollHeight': 0,
#    u'scrollLeft': 0,
#    u'scrollTop': 0,
#    u'scrollWidth': 0,
#    u'spellcheck': True,
#    u'tabIndex': -1,
#    u'tagName': u'B',
#    u'textContent': u'Hello from jQueryUI',
#    u'title': u'',
#    u'translate': True,
#    u'webkitdropzone': u''},
#   u'lastElementChild': {u'ATTRIBUTE_NODE': 2,
#    u'CDATA_SECTION_NODE': 4,
#    u'COMMENT_NODE': 8,
#    u'DOCUMENT_FRAGMENT_NODE': 11,
#    u'DOCUMENT_NODE': 9,
#    u'DOCUMENT_POSITION_CONTAINED_BY': 16,
#    u'DOCUMENT_POSITION_CONTAINS': 8,
#    u'DOCUMENT_POSITION_DISCONNECTED': 1,
#    u'DOCUMENT_POSITION_FOLLOWING': 4,
#    u'DOCUMENT_POSITION_IMPLEMENTATION_SPECIFIC': 32,
#    u'DOCUMENT_POSITION_PRECEDING': 2,
#    u'DOCUMENT_TYPE_NODE': 10,
#    u'ELEMENT_NODE': 1,
#    u'ENTITY_NODE': 6,
#    u'ENTITY_REFERENCE_NODE': 5,
#    u'NOTATION_NODE': 12,
#    u'PROCESSING_INSTRUCTION_NODE': 7,
#    u'TEXT_NODE': 3,
#    u'accessKey': u'',
#    u'baseURI': u'http://localhost:8888/notebooks/repos/jp_gene_viz/examples/js_proxy%20example.ipynb#',
#    u'childElementCount': 0,
#    u'className': u'',
#    u'clientHeight': 0,
#    u'clientLeft': 0,
#    u'clientTop': 0,
#    u'clientWidth': 0,
#    u'contentEditable': u'inherit',
#    u'dir': u'',
#    u'draggable': False,
#    u'hidden': False,
#    u'id': u'my_dialog',
#    u'innerHTML': u'Hello from jQueryUI',
#    u'innerText': u'Hello from jQueryUI',
#    u'isContentEditable': False,
#    u'lang': u'',
#    u'localName': u'b',
#    u'namespaceURI': u'http://www.w3.org/1999/xhtml',
#    u'nodeName': u'B',
#    u'nodeType': 1,
#    u'offsetHeight': 0,
#    u'offsetLeft': 0,
#    u'offsetTop': 0,
#    u'offsetWidth': 0,
#    u'outerHTML': u'<b id="my_dialog">Hello from jQueryUI</b>',
#    u'outerText': u'Hello from jQueryUI',
#    u'scrollHeight': 0,
#    u'scrollLeft': 0,
#    u'scrollTop': 0,
#    u'scrollWidth': 0,
#    u'spellcheck': True,
#    u'tabIndex': -1,
#    u'tagName': u'B',
#    u'textContent': u'Hello from jQueryUI',
#    u'title': u'',
#    u'translate': True,
#    u'webkitdropzone': u''},
#   u'localName': u'div',
#   u'lookupNamespaceURI': {},
#   u'lookupPrefix': {},
#   u'matches': {},
#   u'namespaceURI': u'http://www.w3.org/1999/xhtml',
#   u'nextElementSibling': {u'ATTRIBUTE_NODE': 2,
#    u'CDATA_SECTION_NODE': 4,
#    u'COMMENT_NODE': 8,
#    u'DOCUMENT_FRAGMENT_NODE': 11,
#    u'DOCUMENT_NODE': 9,
#    u'DOCUMENT_POSITION_CONTAINED_BY': 16,
#    u'DOCUMENT_POSITION_CONTAINS': 8,
#    u'DOCUMENT_POSITION_DISCONNECTED': 1,
#    u'DOCUMENT_POSITION_FOLLOWING': 4,
#    u'DOCUMENT_POSITION_IMPLEMENTATION_SPECIFIC': 32,
#    u'DOCUMENT_POSITION_PRECEDING': 2,
#    u'DOCUMENT_TYPE_NODE': 10,
#    u'ELEMENT_NODE': 1,
#    u'ENTITY_NODE': 6,
#    u'ENTITY_REFERENCE_NODE': 5,
#    u'NOTATION_NODE': 12,
#    u'PROCESSING_INSTRUCTION_NODE': 7,
#    u'TEXT_NODE': 3,
#    u'accessKey': u'',
#    u'align': u'',
#    u'baseURI': u'http://localhost:8888/notebooks/repos/jp_gene_viz/examples/js_proxy%20example.ipynb#',
#    u'childElementCount': 0,
#    u'className': u'ui-resizable-handle ui-resizable-n',
#    u'clientHeight': 0,
#    u'clientLeft': 0,
#    u'clientTop': 0,
#    u'clientWidth': 0,
#    u'contentEditable': u'inherit',
#    u'dir': u'',
#    u'draggable': False,
#    u'hidden': False,
#    u'id': u'',
#    u'innerHTML': u'',
#    u'innerText': u'',
#    u'isContentEditable': False,
#    u'lang': u'',
#    u'localName': u'div',
#    u'namespaceURI': u'http://www.w3.org/1999/xhtml',
#    u'nodeName': u'DIV',
#    u'nodeType': 1,
#    u'offsetHeight': 0,
#    u'offsetLeft': 0,
#    u'offsetTop': 0,
#    u'offsetWidth': 0,
#    u'outerHTML': u'<div class="ui-resizable-handle ui-resizable-n" style="z-index: 90;"></div>',
#    u'outerText': u'',
#    u'scrollHeight': 0,
#    u'scrollLeft': 0,
#    u'scrollTop': 0,
#    u'scrollWidth': 0,
#    u'spellcheck': True,
#    u'tabIndex': -1,
#    u'tagName': u'DIV',
#    u'textContent': u'',
#    u'title': u'',
#    u'translate': True,
#    u'webkitdropzone': u''},
#   u'nextSibling': {u'ATTRIBUTE_NODE': 2,
#    u'CDATA_SECTION_NODE': 4,
#    u'COMMENT_NODE': 8,
#    u'DOCUMENT_FRAGMENT_NODE': 11,
#    u'DOCUMENT_NODE': 9,
#    u'DOCUMENT_POSITION_CONTAINED_BY': 16,
#    u'DOCUMENT_POSITION_CONTAINS': 8,
#    u'DOCUMENT_POSITION_DISCONNECTED': 1,
#    u'DOCUMENT_POSITION_FOLLOWING': 4,
#    u'DOCUMENT_POSITION_IMPLEMENTATION_SPECIFIC': 32,
#    u'DOCUMENT_POSITION_PRECEDING': 2,
#    u'DOCUMENT_TYPE_NODE': 10,
#    u'ELEMENT_NODE': 1,
#    u'ENTITY_NODE': 6,
#    u'ENTITY_REFERENCE_NODE': 5,
#    u'NOTATION_NODE': 12,
#    u'PROCESSING_INSTRUCTION_NODE': 7,
#    u'TEXT_NODE': 3,
#    u'accessKey': u'',
#    u'align': u'',
#    u'baseURI': u'http://localhost:8888/notebooks/repos/jp_gene_viz/examples/js_proxy%20example.ipynb#',
#    u'childElementCount': 0,
#    u'className': u'ui-resizable-handle ui-resizable-n',
#    u'clientHeight': 0,
#    u'clientLeft': 0,
#    u'clientTop': 0,
#    u'clientWidth': 0,
#    u'contentEditable': u'inherit',
#    u'dir': u'',
#    u'draggable': False,
#    u'hidden': False,
#    u'id': u'',
#    u'innerHTML': u'',
#    u'innerText': u'',
#    u'isContentEditable': False,
#    u'lang': u'',
#    u'localName': u'div',
#    u'namespaceURI': u'http://www.w3.org/1999/xhtml',
#    u'nodeName': u'DIV',
#    u'nodeType': 1,
#    u'offsetHeight': 0,
#    u'offsetLeft': 0,
#    u'offsetTop': 0,
#    u'offsetWidth': 0,
#    u'outerHTML': u'<div class="ui-resizable-handle ui-resizable-n" style="z-index: 90;"></div>',
#    u'outerText': u'',
#    u'scrollHeight': 0,
#    u'scrollLeft': 0,
#    u'scrollTop': 0,
#    u'scrollWidth': 0,
#    u'spellcheck': True,
#    u'tabIndex': -1,
#    u'tagName': u'DIV',
#    u'textContent': u'',
#    u'title': u'',
#    u'translate': True,
#    u'webkitdropzone': u''},
#   u'nodeName': u'DIV',
#   u'nodeType': 1,
#   u'normalize': {},
#   u'offsetHeight': 0,
#   u'offsetLeft': 0,
#   u'offsetTop': 0,
#   u'offsetWidth': 0,
#   u'outerHTML': u'<div id="ui-id-3" class="ui-dialog-content ui-widget-content" style="min-height: 92px; max-height: none; width: auto; height: auto;"><b id="my_dialog">Hello from jQueryUI</b></div>',
#   u'outerText': u'Hello from jQueryUI',
#   u'ownerDocument': {u'ATTRIBUTE_NODE': 2,
#    u'CDATA_SECTION_NODE': 4,
#    u'COMMENT_NODE': 8,
#    u'DOCUMENT_FRAGMENT_NODE': 11,
#    u'DOCUMENT_NODE': 9,
#    u'DOCUMENT_POSITION_CONTAINED_BY': 16,
#    u'DOCUMENT_POSITION_CONTAINS': 8,
#    u'DOCUMENT_POSITION_DISCONNECTED': 1,
#    u'DOCUMENT_POSITION_FOLLOWING': 4,
#    u'DOCUMENT_POSITION_IMPLEMENTATION_SPECIFIC': 32,
#    u'DOCUMENT_POSITION_PRECEDING': 2,
#    u'DOCUMENT_TYPE_NODE': 10,
#    u'ELEMENT_NODE': 1,
#    u'ENTITY_NODE': 6,
#    u'ENTITY_REFERENCE_NODE': 5,
#    u'NOTATION_NODE': 12,
#    u'PROCESSING_INSTRUCTION_NODE': 7,
#    u'TEXT_NODE': 3,
#    u'URL': u'http://localhost:8888/notebooks/repos/jp_gene_viz/examples/js_proxy%20example.ipynb#',
#    u'alinkColor': u'',
#    u'baseURI': u'http://localhost:8888/notebooks/repos/jp_gene_viz/examples/js_proxy%20example.ipynb#',
#    u'bgColor': u'',
#    u'characterSet': u'UTF-8',
#    u'charset': u'UTF-8',
#    u'childElementCount': 1,
#    u'compatMode': u'CSS1Compat',
#    u'contentType': u'text/html',
#    u'cookie': u'',
#    u'defaultCharset': u'windows-1252',
#    u'designMode': u'off',
#    u'dir': u'',
#    u'documentURI': u'http://localhost:8888/notebooks/repos/jp_gene_viz/examples/js_proxy%20example.ipynb#',
#    u'domain': u'localhost',
#    u'fgColor': u'',
#    u'hidden': False,
#    u'inputEncoding': u'UTF-8',
#    u'lastModified': u'11/11/2015 15:43:25',
#    u'linkColor': u'',
#    u'nodeName': u'#document',
#    u'nodeType': 9,
#    u'origin': u'http://localhost:8888',
#    u'readyState': u'complete',
#    u'referrer': u'http://localhost:8888/tree/repos/jp_gene_viz/examples',
#    u'title': u'(Busy) js_proxy example',
#    u'visibilityState': u'visible',
#    u'vlinkColor': u'',
#    u'webkitFullscreenEnabled': True,
#    u'webkitHidden': False,
#    u'webkitIsFullScreen': False,
#    u'webkitVisibilityState': u'visible',
#    u'xmlStandalone': False},
#   u'parentElement': {u'ATTRIBUTE_NODE': 2,
#    u'CDATA_SECTION_NODE': 4,
#    u'COMMENT_NODE': 8,
#    u'DOCUMENT_FRAGMENT_NODE': 11,
#    u'DOCUMENT_NODE': 9,
#    u'DOCUMENT_POSITION_CONTAINED_BY': 16,
#    u'DOCUMENT_POSITION_CONTAINS': 8,
#    u'DOCUMENT_POSITION_DISCONNECTED': 1,
#    u'DOCUMENT_POSITION_FOLLOWING': 4,
#    u'DOCUMENT_POSITION_IMPLEMENTATION_SPECIFIC': 32,
#    u'DOCUMENT_POSITION_PRECEDING': 2,
#    u'DOCUMENT_TYPE_NODE': 10,
#    u'ELEMENT_NODE': 1,
#    u'ENTITY_NODE': 6,
#    u'ENTITY_REFERENCE_NODE': 5,
#    u'NOTATION_NODE': 12,
#    u'PROCESSING_INSTRUCTION_NODE': 7,
#    u'TEXT_NODE': 3,
#    u'accessKey': u'',
#    u'align': u'',
#    u'baseURI': u'http://localhost:8888/notebooks/repos/jp_gene_viz/examples/js_proxy%20example.ipynb#',
#    u'childElementCount': 10,
#    u'className': u'ui-dialog ui-widget ui-widget-content ui-corner-all ui-front ui-draggable ui-resizable',
#    u'clientHeight': 0,
#    u'clientLeft': 0,
#    u'clientTop': 0,
#    u'clientWidth': 0,
#    u'contentEditable': u'inherit',
#    u'dir': u'',
#    u'draggable': False,
#    u'hidden': False,
#    u'id': u'',
#    u'innerHTML': u'<div class="ui-dialog-titlebar ui-widget-header ui-corner-all ui-helper-clearfix"><span id="ui-id-4" class="ui-dialog-title">&nbsp;</span><button type="button" class="ui-dialog-titlebar-close"></button></div><div id="ui-id-3" class="ui-dialog-content ui-widget-content" style="min-height: 92px; max-height: none; width: auto; height: auto;"><b id="my_dialog">Hello from jQueryUI</b></div><div class="ui-resizable-handle ui-resizable-n" style="z-index: 90;"></div><div class="ui-resizable-handle ui-resizable-e" style="z-index: 90;"></div><div class="ui-resizable-handle ui-resizable-s" style="z-index: 90;"></div><div class="ui-resizable-handle ui-resizable-w" style="z-index: 90;"></div><div class="ui-resizable-handle ui-resizable-se ui-icon ui-icon-gripsmall-diagonal-se" style="z-index: 90;"></div><div class="ui-resizable-handle ui-resizable-sw" style="z-index: 90;"></div><div class="ui-resizable-handle ui-resizable-ne" style="z-index: 90;"></div><div class="ui-resizable-handle ui-resizable-nw" style="z-index: 90;"></div>',
#    u'innerText': u'\xa0Hello from jQueryUI',
#    u'isContentEditable': False,
#    u'lang': u'',
#    u'localName': u'div',
#    u'namespaceURI': u'http://www.w3.org/1999/xhtml',
#    u'nodeName': u'DIV',
#    u'nodeType': 1,
#    u'offsetHeight': 0,
#    u'offsetLeft': 0,
#    u'offsetTop': 0,
#    u'offsetWidth': 0,
#    u'outerHTML': u'<div class="ui-dialog ui-widget ui-widget-content ui-corner-all ui-front ui-draggable ui-resizable" tabindex="-1" role="dialog" aria-describedby="ui-id-3" aria-labelledby="ui-id-4" style="position: absolute; height: auto; width: 300px; top: 466px; left: 544px; display: none;"><div class="ui-dialog-titlebar ui-widget-header ui-corner-all ui-helper-clearfix"><span id="ui-id-4" class="ui-dialog-title">&nbsp;</span><button type="button" class="ui-dialog-titlebar-close"></button></div><div id="ui-id-3" class="ui-dialog-content ui-widget-content" style="min-height: 92px; max-height: none; width: auto; height: auto;"><b id="my_dialog">Hello from jQueryUI</b></div><div class="ui-resizable-handle ui-resizable-n" style="z-index: 90;"></div><div class="ui-resizable-handle ui-resizable-e" style="z-index: 90;"></div><div class="ui-resizable-handle ui-resizable-s" style="z-index: 90;"></div><div class="ui-resizable-handle ui-resizable-w" style="z-index: 90;"></div><div class="ui-resizable-handle ui-resizable-se ui-icon ui-icon-gripsmall-diagonal-se" style="z-index: 90;"></div><div class="ui-resizable-handle ui-resizable-sw" style="z-index: 90;"></div><div class="ui-resizable-handle ui-resizable-ne" style="z-index: 90;"></div><div class="ui-resizable-handle ui-resizable-nw" style="z-index: 90;"></div></div>',
#    u'outerText': u'\xa0Hello from jQueryUI',
#    u'scrollHeight': 0,
#    u'scrollLeft': 0,
#    u'scrollTop': 0,
#    u'scrollWidth': 0,
#    u'spellcheck': True,
#    u'tabIndex': -1,
#    u'tagName': u'DIV',
#    u'textContent': u'\xa0Hello from jQueryUI',
#    u'title': u'',
#    u'translate': True,
#    u'webkitdropzone': u''},
#   u'parentNode': {u'ATTRIBUTE_NODE': 2,
#    u'CDATA_SECTION_NODE': 4,
#    u'COMMENT_NODE': 8,
#    u'DOCUMENT_FRAGMENT_NODE': 11,
#    u'DOCUMENT_NODE': 9,
#    u'DOCUMENT_POSITION_CONTAINED_BY': 16,
#    u'DOCUMENT_POSITION_CONTAINS': 8,
#    u'DOCUMENT_POSITION_DISCONNECTED': 1,
#    u'DOCUMENT_POSITION_FOLLOWING': 4,
#    u'DOCUMENT_POSITION_IMPLEMENTATION_SPECIFIC': 32,
#    u'DOCUMENT_POSITION_PRECEDING': 2,
#    u'DOCUMENT_TYPE_NODE': 10,
#    u'ELEMENT_NODE': 1,
#    u'ENTITY_NODE': 6,
#    u'ENTITY_REFERENCE_NODE': 5,
#    u'NOTATION_NODE': 12,
#    u'PROCESSING_INSTRUCTION_NODE': 7,
#    u'TEXT_NODE': 3,
#    u'accessKey': u'',
#    u'align': u'',
#    u'baseURI': u'http://localhost:8888/notebooks/repos/jp_gene_viz/examples/js_proxy%20example.ipynb#',
#    u'childElementCount': 10,
#    u'className': u'ui-dialog ui-widget ui-widget-content ui-corner-all ui-front ui-draggable ui-resizable',
#    u'clientHeight': 0,
#    u'clientLeft': 0,
#    u'clientTop': 0,
#    u'clientWidth': 0,
#    u'contentEditable': u'inherit',
#    u'dir': u'',
#    u'draggable': False,
#    u'hidden': False,
#    u'id': u'',
#    u'innerHTML': u'<div class="ui-dialog-titlebar ui-widget-header ui-corner-all ui-helper-clearfix"><span id="ui-id-4" class="ui-dialog-title">&nbsp;</span><button type="button" class="ui-dialog-titlebar-close"></button></div><div id="ui-id-3" class="ui-dialog-content ui-widget-content" style="min-height: 92px; max-height: none; width: auto; height: auto;"><b id="my_dialog">Hello from jQueryUI</b></div><div class="ui-resizable-handle ui-resizable-n" style="z-index: 90;"></div><div class="ui-resizable-handle ui-resizable-e" style="z-index: 90;"></div><div class="ui-resizable-handle ui-resizable-s" style="z-index: 90;"></div><div class="ui-resizable-handle ui-resizable-w" style="z-index: 90;"></div><div class="ui-resizable-handle ui-resizable-se ui-icon ui-icon-gripsmall-diagonal-se" style="z-index: 90;"></div><div class="ui-resizable-handle ui-resizable-sw" style="z-index: 90;"></div><div class="ui-resizable-handle ui-resizable-ne" style="z-index: 90;"></div><div class="ui-resizable-handle ui-resizable-nw" style="z-index: 90;"></div>',
#    u'innerText': u'\xa0Hello from jQueryUI',
#    u'isContentEditable': False,
#    u'lang': u'',
#    u'localName': u'div',
#    u'namespaceURI': u'http://www.w3.org/1999/xhtml',
#    u'nodeName': u'DIV',
#    u'nodeType': 1,
#    u'offsetHeight': 0,
#    u'offsetLeft': 0,
#    u'offsetTop': 0,
#    u'offsetWidth': 0,
#    u'outerHTML': u'<div class="ui-dialog ui-widget ui-widget-content ui-corner-all ui-front ui-draggable ui-resizable" tabindex="-1" role="dialog" aria-describedby="ui-id-3" aria-labelledby="ui-id-4" style="position: absolute; height: auto; width: 300px; top: 466px; left: 544px; display: none;"><div class="ui-dialog-titlebar ui-widget-header ui-corner-all ui-helper-clearfix"><span id="ui-id-4" class="ui-dialog-title">&nbsp;</span><button type="button" class="ui-dialog-titlebar-close"></button></div><div id="ui-id-3" class="ui-dialog-content ui-widget-content" style="min-height: 92px; max-height: none; width: auto; height: auto;"><b id="my_dialog">Hello from jQueryUI</b></div><div class="ui-resizable-handle ui-resizable-n" style="z-index: 90;"></div><div class="ui-resizable-handle ui-resizable-e" style="z-index: 90;"></div><div class="ui-resizable-handle ui-resizable-s" style="z-index: 90;"></div><div class="ui-resizable-handle ui-resizable-w" style="z-index: 90;"></div><div class="ui-resizable-handle ui-resizable-se ui-icon ui-icon-gripsmall-diagonal-se" style="z-index: 90;"></div><div class="ui-resizable-handle ui-resizable-sw" style="z-index: 90;"></div><div class="ui-resizable-handle ui-resizable-ne" style="z-index: 90;"></div><div class="ui-resizable-handle ui-resizable-nw" style="z-index: 90;"></div></div>',
#    u'outerText': u'\xa0Hello from jQueryUI',
#    u'scrollHeight': 0,
#    u'scrollLeft': 0,
#    u'scrollTop': 0,
#    u'scrollWidth': 0,
#    u'spellcheck': True,
#    u'tabIndex': -1,
#    u'tagName': u'DIV',
#    u'textContent': u'\xa0Hello from jQueryUI',
#    u'title': u'',
#    u'translate': True,
#    u'webkitdropzone': u''},
#   u'previousElementSibling': {u'ATTRIBUTE_NODE': 2,
#    u'CDATA_SECTION_NODE': 4,
#    u'COMMENT_NODE': 8,
#    u'DOCUMENT_FRAGMENT_NODE': 11,
#    u'DOCUMENT_NODE': 9,
#    u'DOCUMENT_POSITION_CONTAINED_BY': 16,
#    u'DOCUMENT_POSITION_CONTAINS': 8,
#    u'DOCUMENT_POSITION_DISCONNECTED': 1,
#    u'DOCUMENT_POSITION_FOLLOWING': 4,
#    u'DOCUMENT_POSITION_IMPLEMENTATION_SPECIFIC': 32,
#    u'DOCUMENT_POSITION_PRECEDING': 2,
#    u'DOCUMENT_TYPE_NODE': 10,
#    u'ELEMENT_NODE': 1,
#    u'ENTITY_NODE': 6,
#    u'ENTITY_REFERENCE_NODE': 5,
#    u'NOTATION_NODE': 12,
#    u'PROCESSING_INSTRUCTION_NODE': 7,
#    u'TEXT_NODE': 3,
#    u'accessKey': u'',
#    u'align': u'',
#    u'baseURI': u'http://localhost:8888/notebooks/repos/jp_gene_viz/examples/js_proxy%20example.ipynb#',
#    u'childElementCount': 2,
#    u'className': u'ui-dialog-titlebar ui-widget-header ui-corner-all ui-helper-clearfix',
#    u'clientHeight': 0,
#    u'clientLeft': 0,
#    u'clientTop': 0,
#    u'clientWidth': 0,
#    u'contentEditable': u'inherit',
#    u'dir': u'',
#    u'draggable': False,
#    u'hidden': False,
#    u'id': u'',
#    u'innerHTML': u'<span id="ui-id-4" class="ui-dialog-title">&nbsp;</span><button type="button" class="ui-dialog-titlebar-close"></button>',
#    u'innerText': u'\xa0',
#    u'isContentEditable': False,
#    u'lang': u'',
#    u'localName': u'div',
#    u'namespaceURI': u'http://www.w3.org/1999/xhtml',
#    u'nodeName': u'DIV',
#    u'nodeType': 1,
#    u'offsetHeight': 0,
#    u'offsetLeft': 0,
#    u'offsetTop': 0,
#    u'offsetWidth': 0,
#    u'outerHTML': u'<div class="ui-dialog-titlebar ui-widget-header ui-corner-all ui-helper-clearfix"><span id="ui-id-4" class="ui-dialog-title">&nbsp;</span><button type="button" class="ui-dialog-titlebar-close"></button></div>',
#    u'outerText': u'\xa0',
#    u'scrollHeight': 0,
#    u'scrollLeft': 0,
#    u'scrollTop': 0,
#    u'scrollWidth': 0,
#    u'spellcheck': True,
#    u'tabIndex': -1,
#    u'tagName': u'DIV',
#    u'textContent': u'\xa0',
#    u'title': u'',
#    u'translate': True,
#    u'webkitdropzone': u''},
#   u'previousSibling': {u'ATTRIBUTE_NODE': 2,
#    u'CDATA_SECTION_NODE': 4,
#    u'COMMENT_NODE': 8,
#    u'DOCUMENT_FRAGMENT_NODE': 11,
#    u'DOCUMENT_NODE': 9,
#    u'DOCUMENT_POSITION_CONTAINED_BY': 16,
#    u'DOCUMENT_POSITION_CONTAINS': 8,
#    u'DOCUMENT_POSITION_DISCONNECTED': 1,
#    u'DOCUMENT_POSITION_FOLLOWING': 4,
#    u'DOCUMENT_POSITION_IMPLEMENTATION_SPECIFIC': 32,
#    u'DOCUMENT_POSITION_PRECEDING': 2,
#    u'DOCUMENT_TYPE_NODE': 10,
#    u'ELEMENT_NODE': 1,
#    u'ENTITY_NODE': 6,
#    u'ENTITY_REFERENCE_NODE': 5,
#    u'NOTATION_NODE': 12,
#    u'PROCESSING_INSTRUCTION_NODE': 7,
#    u'TEXT_NODE': 3,
#    u'accessKey': u'',
#    u'align': u'',
#    u'baseURI': u'http://localhost:8888/notebooks/repos/jp_gene_viz/examples/js_proxy%20example.ipynb#',
#    u'childElementCount': 2,
#    u'className': u'ui-dialog-titlebar ui-widget-header ui-corner-all ui-helper-clearfix',
#    u'clientHeight': 0,
#    u'clientLeft': 0,
#    u'clientTop': 0,
#    u'clientWidth': 0,
#    u'contentEditable': u'inherit',
#    u'dir': u'',
#    u'draggable': False,
#    u'hidden': False,
#    u'id': u'',
#    u'innerHTML': u'<span id="ui-id-4" class="ui-dialog-title">&nbsp;</span><button type="button" class="ui-dialog-titlebar-close"></button>',
#    u'innerText': u'\xa0',
#    u'isContentEditable': False,
#    u'lang': u'',
#    u'localName': u'div',
#    u'namespaceURI': u'http://www.w3.org/1999/xhtml',
#    u'nodeName': u'DIV',
#    u'nodeType': 1,
#    u'offsetHeight': 0,
#    u'offsetLeft': 0,
#    u'offsetTop': 0,
#    u'offsetWidth': 0,
#    u'outerHTML': u'<div class="ui-dialog-titlebar ui-widget-header ui-corner-all ui-helper-clearfix"><span id="ui-id-4" class="ui-dialog-title">&nbsp;</span><button type="button" class="ui-dialog-titlebar-close"></button></div>',
#    u'outerText': u'\xa0',
#    u'scrollHeight': 0,
#    u'scrollLeft': 0,
#    u'scrollTop': 0,
#    u'scrollWidth': 0,
#    u'spellcheck': True,
#    u'tabIndex': -1,
#    u'tagName': u'DIV',
#    u'textContent': u'\xa0',
#    u'title': u'',
#    u'translate': True,
#    u'webkitdropzone': u''},
#   u'querySelector': {},
#   u'querySelectorAll': {},
#   u'remove': {},
#   u'removeAttribute': {},
#   u'removeAttributeNS': {},
#   u'removeAttributeNode': {},
#   u'removeChild': {},
#   u'removeEventListener': {},
#   u'replaceChild': {},
#   u'requestPointerLock': {},
#   u'scrollHeight': 0,
#   u'scrollIntoView': {},
#   u'scrollIntoViewIfNeeded': {},
#   u'scrollLeft': 0,
#   u'scrollTop': 0,
#   u'scrollWidth': 0,
#   u'setAttribute': {},
#   u'setAttributeNS': {},
#   u'setAttributeNode': {},
#   u'setAttributeNodeNS': {},
#   u'spellcheck': True,
#   u'style': {u'0': u'min-height',
#    u'1': u'max-height',
#    u'2': u'width',
#    u'3': u'height',
#    u'alignContent': u'',
#    u'alignItems': u'',
#    u'alignSelf': u'',
#    u'alignmentBaseline': u'',
#    u'all': u'',
#    u'animation': u'',
#    u'animationDelay': u'',
#    u'animationDirection': u'',
#    u'animationDuration': u'',
#    u'animationFillMode': u'',
#    u'animationIterationCount': u'',
#    u'animationName': u'',
#    u'animationPlayState': u'',
#    u'animationTimingFunction': u'',
#    u'backfaceVisibility': u'',
#    u'background': u'',
#    u'backgroundAttachment': u'',
#    u'backgroundBlendMode': u'',
#    u'backgroundClip': u'',
#    u'backgroundColor': u'',
#    u'backgroundImage': u'',
#    u'backgroundOrigin': u'',
#    u'backgroundPosition': u'',
#    u'backgroundPositionX': u'',
#    u'backgroundPositionY': u'',
#    u'backgroundRepeat': u'',
#    u'backgroundRepeatX': u'',
#    u'backgroundRepeatY': u'',
#    u'backgroundSize': u'',
#    u'baselineShift': u'',
#    u'border': u'',
#    u'borderBottom': u'',
#    u'borderBottomColor': u'',
#    u'borderBottomLeftRadius': u'',
#    u'borderBottomRightRadius': u'',
#    u'borderBottomStyle': u'',
#    u'borderBottomWidth': u'',
#    u'borderCollapse': u'',
#    u'borderColor': u'',
#    u'borderImage': u'',
#    u'borderImageOutset': u'',
#    u'borderImageRepeat': u'',
#    u'borderImageSlice': u'',
#    u'borderImageSource': u'',
#    u'borderImageWidth': u'',
#    u'borderLeft': u'',
#    u'borderLeftColor': u'',
#    u'borderLeftStyle': u'',
#    u'borderLeftWidth': u'',
#    u'borderRadius': u'',
#    u'borderRight': u'',
#    u'borderRightColor': u'',
#    u'borderRightStyle': u'',
#    u'borderRightWidth': u'',
#    u'borderSpacing': u'',
#    u'borderStyle': u'',
#    u'borderTop': u'',
#    u'borderTopColor': u'',
#    u'borderTopLeftRadius': u'',
#    u'borderTopRightRadius': u'',
#    u'borderTopStyle': u'',
#    u'borderTopWidth': u'',
#    u'borderWidth': u'',
#    u'bottom': u'',
#    u'boxShadow': u'',
#    u'boxSizing': u'',
#    u'bufferedRendering': u'',
#    u'captionSide': u'',
#    u'clear': u'',
#    u'clip': u'',
#    u'clipPath': u'',
#    u'clipRule': u'',
#    u'color': u'',
#    u'colorInterpolation': u'',
#    u'colorInterpolationFilters': u'',
#    u'colorRendering': u'',
#    u'content': u'',
#    u'counterIncrement': u'',
#    u'counterReset': u'',
#    u'cssFloat': u'',
#    u'cssText': u'min-height: 92px; max-height: none; width: auto; height: auto;',
#    u'cursor': u'',
#    u'cx': u'',
#    u'cy': u'',
#    u'direction': u'',
#    u'display': u'',
#    u'dominantBaseline': u'',
#    u'emptyCells': u'',
#    u'fill': u'',
#    u'fillOpacity': u'',
#    u'fillRule': u'',
#    u'filter': u'',
#    u'flex': u'',
#    u'flexBasis': u'',
#    u'flexDirection': u'',
#    u'flexFlow': u'',
#    u'flexGrow': u'',
#    u'flexShrink': u'',
#    u'flexWrap': u'',
#    u'float': u'',
#    u'floodColor': u'',
#    u'floodOpacity': u'',
#    u'font': u'',
#    u'fontFamily': u'',
#    u'fontKerning': u'',
#    u'fontSize': u'',
#    u'fontStretch': u'',
#    u'fontStyle': u'',
#    u'fontVariant': u'',
#    u'fontVariantLigatures': u'',
#    u'fontWeight': u'',
#    u'glyphOrientationHorizontal': u'',
#    u'glyphOrientationVertical': u'',
#    u'height': u'auto',
#    u'imageRendering': u'',
#    u'isolation': u'',
#    u'justifyContent': u'',
#    u'left': u'',
#    u'length': 4,
#    u'letterSpacing': u'',
#    u'lightingColor': u'',
#    u'lineHeight': u'',
#    u'listStyle': u'',
#    u'listStyleImage': u'',
#    u'listStylePosition': u'',
#    u'listStyleType': u'',
#    u'margin': u'',
#    u'marginBottom': u'',
#    u'marginLeft': u'',
#    u'marginRight': u'',
#    u'marginTop': u'',
#    u'marker': u'',
#    u'markerEnd': u'',
#    u'markerMid': u'',
#    u'markerStart': u'',
#    u'mask': u'',
#    u'maskType': u'',
#    u'maxHeight': u'none',
#    u'maxWidth': u'',
#    u'maxZoom': u'',
#    u'minHeight': u'92px',
#    u'minWidth': u'',
#    u'minZoom': u'',
#    u'mixBlendMode': u'',
#    u'motion': u'',
#    u'motionOffset': u'',
#    u'motionPath': u'',
#    u'motionRotation': u'',
#    u'objectFit': u'',
#    u'objectPosition': u'',
#    u'opacity': u'',
#    u'order': u'',
#    u'orientation': u'',
#    u'orphans': u'',
#    u'outline': u'',
#    u'outlineColor': u'',
#    u'outlineOffset': u'',
#    u'outlineStyle': u'',
#    u'outlineWidth': u'',
#    u'overflow': u'',
#    u'overflowWrap': u'',
#    u'overflowX': u'',
#    u'overflowY': u'',
#    u'padding': u'',
#    u'paddingBottom': u'',
#    u'paddingLeft': u'',
#    u'paddingRight': u'',
#    u'paddingTop': u'',
#    u'page': u'',
#    u'pageBreakAfter': u'',
#    u'pageBreakBefore': u'',
#    u'pageBreakInside': u'',
#    u'paintOrder': u'',
#    u'perspective': u'',
#    u'perspectiveOrigin': u'',
#    u'pointerEvents': u'',
#    u'position': u'',
#    u'quotes': u'',
#    u'r': u'',
#    u'resize': u'',
#    u'right': u'',
#    u'rx': u'',
#    u'ry': u'',
#    u'shapeImageThreshold': u'',
#    u'shapeMargin': u'',
#    u'shapeOutside': u'',
#    u'shapeRendering': u'',
#    u'size': u'',
#    u'speak': u'',
#    u'src': u'',
#    u'stopColor': u'',
#    u'stopOpacity': u'',
#    u'stroke': u'',
#    u'strokeDasharray': u'',
#    u'strokeDashoffset': u'',
#    u'strokeLinecap': u'',
#    u'strokeLinejoin': u'',
#    u'strokeMiterlimit': u'',
#    u'strokeOpacity': u'',
#    u'strokeWidth': u'',
#    u'tabSize': u'',
#    u'tableLayout': u'',
#    u'textAlign': u'',
#    u'textAnchor': u'',
#    u'textDecoration': u'',
#    u'textIndent': u'',
#    u'textOverflow': u'',
#    u'textRendering': u'',
#    u'textShadow': u'',
#    u'textTransform': u'',
#    u'top': u'',
#    u'touchAction': u'',
#    u'transform': u'',
#    u'transformOrigin': u'',
#    u'transformStyle': u'',
#    u'transition': u'',
#    u'transitionDelay': u'',
#    u'transitionDuration': u'',
#    u'transitionProperty': u'',
#    u'transitionTimingFunction': u'',
#    u'unicodeBidi': u'',
#    u'unicodeRange': u'',
#    u'userZoom': u'',
#    u'vectorEffect': u'',
#    u'verticalAlign': u'',
#    u'visibility': u'',
#    u'webkitAppRegion': u'',
#    u'webkitAppearance': u'',
#    u'webkitBackgroundClip': u'',
#    u'webkitBackgroundComposite': u'',
#    u'webkitBackgroundOrigin': u'',
#    u'webkitBorderAfter': u'',
#    u'webkitBorderAfterColor': u'',
#    u'webkitBorderAfterStyle': u'',
#    u'webkitBorderAfterWidth': u'',
#    u'webkitBorderBefore': u'',
#    u'webkitBorderBeforeColor': u'',
#    u'webkitBorderBeforeStyle': u'',
#    u'webkitBorderBeforeWidth': u'',
#    u'webkitBorderEnd': u'',
#    u'webkitBorderEndColor': u'',
#    u'webkitBorderEndStyle': u'',
#    u'webkitBorderEndWidth': u'',
#    u'webkitBorderHorizontalSpacing': u'',
#    u'webkitBorderImage': u'',
#    u'webkitBorderStart': u'',
#    u'webkitBorderStartColor': u'',
#    u'webkitBorderStartStyle': u'',
#    u'webkitBorderStartWidth': u'',
#    u'webkitBorderVerticalSpacing': u'',
#    u'webkitBoxAlign': u'',
#    u'webkitBoxDecorationBreak': u'',
#    u'webkitBoxDirection': u'',
#    u'webkitBoxFlex': u'',
#    u'webkitBoxFlexGroup': u'',
#    u'webkitBoxLines': u'',
#    u'webkitBoxOrdinalGroup': u'',
#    u'webkitBoxOrient': u'',
#    u'webkitBoxPack': u'',
#    u'webkitBoxReflect': u'',
#    u'webkitClipPath': u'',
#    u'webkitColumnBreakAfter': u'',
#    u'webkitColumnBreakBefore': u'',
#    u'webkitColumnBreakInside': u'',
#    u'webkitColumnCount': u'',
#    u'webkitColumnGap': u'',
#    u'webkitColumnRule': u'',
#    u'webkitColumnRuleColor': u'',
#    u'webkitColumnRuleStyle': u'',
#    u'webkitColumnRuleWidth': u'',
#    u'webkitColumnSpan': u'',
#    u'webkitColumnWidth': u'',
#    u'webkitColumns': u'',
#    u'webkitFilter': u'',
#    u'webkitFontFeatureSettings': u'',
#    u'webkitFontSizeDelta': u'',
#    u'webkitFontSmoothing': u'',
#    u'webkitHighlight': u'',
#    u'webkitHyphenateCharacter': u'',
#    u'webkitLineBoxContain': u'',
#    u'webkitLineBreak': u'',
#    u'webkitLineClamp': u'',
#    u'webkitLocale': u'',
#    u'webkitLogicalHeight': u'',
#    u'webkitLogicalWidth': u'',
#    u'webkitMarginAfter': u'',
#    u'webkitMarginAfterCollapse': u'',
#    u'webkitMarginBefore': u'',
#    u'webkitMarginBeforeCollapse': u'',
#    u'webkitMarginBottomCollapse': u'',
#    u'webkitMarginCollapse': u'',
#    u'webkitMarginEnd': u'',
#    u'webkitMarginStart': u'',
#    u'webkitMarginTopCollapse': u'',
#    u'webkitMask': u'',
#    u'webkitMaskBoxImage': u'',
#    u'webkitMaskBoxImageOutset': u'',
#    u'webkitMaskBoxImageRepeat': u'',
#    u'webkitMaskBoxImageSlice': u'',
#    u'webkitMaskBoxImageSource': u'',
#    u'webkitMaskBoxImageWidth': u'',
#    u'webkitMaskClip': u'',
#    u'webkitMaskComposite': u'',
#    u'webkitMaskImage': u'',
#    u'webkitMaskOrigin': u'',
#    u'webkitMaskPosition': u'',
#    u'webkitMaskPositionX': u'',
#    u'webkitMaskPositionY': u'',
#    u'webkitMaskRepeat': u'',
#    u'webkitMaskRepeatX': u'',
#    u'webkitMaskRepeatY': u'',
#    u'webkitMaskSize': u'',
#    u'webkitMaxLogicalHeight': u'',
#    u'webkitMaxLogicalWidth': u'',
#    u'webkitMinLogicalHeight': u'',
#    u'webkitMinLogicalWidth': u'',
#    u'webkitPaddingAfter': u'',
#    u'webkitPaddingBefore': u'',
#    u'webkitPaddingEnd': u'',
#    u'webkitPaddingStart': u'',
#    u'webkitPerspectiveOriginX': u'',
#    u'webkitPerspectiveOriginY': u'',
#    u'webkitPrintColorAdjust': u'',
#    u'webkitRtlOrdering': u'',
#    u'webkitRubyPosition': u'',
#    u'webkitTapHighlightColor': u'',
#    u'webkitTextCombine': u'',
#    u'webkitTextDecorationsInEffect': u'',
#    u'webkitTextEmphasis': u'',
#    u'webkitTextEmphasisColor': u'',
#    u'webkitTextEmphasisPosition': u'',
#    u'webkitTextEmphasisStyle': u'',
#    u'webkitTextFillColor': u'',
#    u'webkitTextOrientation': u'',
#    u'webkitTextSecurity': u'',
#    u'webkitTextStroke': u'',
#    u'webkitTextStrokeColor': u'',
#    u'webkitTextStrokeWidth': u'',
#    u'webkitTransformOriginX': u'',
#    u'webkitTransformOriginY': u'',
#    u'webkitTransformOriginZ': u'',
#    u'webkitUserDrag': u'',
#    u'webkitUserModify': u'',
#    u'webkitUserSelect': u'',
#    u'webkitWritingMode': u'',
#    u'whiteSpace': u'',
#    u'widows': u'',
#    u'width': u'auto',
#    u'willChange': u'',
#    u'wordBreak': u'',
#    u'wordSpacing': u'',
#    u'wordWrap': u'',
#    u'writingMode': u'',
#    u'x': u'',
#    u'y': u'',
#    u'zIndex': u'',
#    u'zoom': u''},
#   u'tabIndex': -1,
#   u'tagName': u'DIV',
#   u'textContent': u'Hello from jQueryUI',
#   u'title': u'',
#   u'translate': True,
#   u'webkitMatchesSelector': {},
#   u'webkitRequestFullScreen': {},
#   u'webkitRequestFullscreen': {},
#   u'webkitdropzone': u''}]

# %% [markdown]
# # Events
#
# The proxy widget method
#
# `w.callback(self, callback_function, data, level=1)`
#
# Sets up the infrastructure for a javascript callback which can communicate
# a callback event notification from Javascript to the Python interpreter.
#
# For example the following code creates an input element with
# "calendar datepicker" jQueryUI functionality and also associates
# a callback to be called when the input value changes.

# %%
# Create the widget.
dp = js_proxy.ProxyWidget()

# Command to populate the widget with an input element with id dp000.
make_input = dp.element().html('<input type="text" id="dp000"/>')._null()

# Command to make the input element into a datepicker and
# fix the style so the datepicker sits on top of the notebook page.
fix_style = (
    dp.window().
    jQuery("#dp000").  # get the jQuery input element by id == "dp".
    datepicker().   # make it a jQuery UI datepicker.
    css("position", "relative").
    css("z-index", "10000").  # put it on top
    attr("size", 55).  # make it big.
    _null()   # we don't care about the command result, discard it.
    )

# Define a python function and data structures to capture
# values sent to the callback when the datepicker input value changes.
identifiers_list = []
arguments_list = []

def dp_change_handler(identifier, arguments):
    "Print the results and also store them in lists."
    print (identifier, arguments['0']['target']['value'])
    identifiers_list.append(identifier)
    arguments_list.append(arguments)
    
# Command to create a "proxy callback" for the change event.
# The proxy will translate values to JSON up to 3 levels deep
# and also send the identifier data "dp has changed" to the handler.
proxy_callback = dp.callback(dp_change_handler, data="dp has changed", level=3)

# Command to associate the proxy callback with the datepicker change event
# using the standard $(x).change(callback) jQuery method.
on_change_command = dp.window().jQuery("#dp000").change(proxy_callback)

# Send the commands to the Javascript view.
dp.send_commands([make_input, fix_style, on_change_command])

# display the widget
display(dp)
# Out:
# (u'dp has changed', u'11/06/2015')

# %% [markdown]
# When you change the value in the datepicker input box
# you should see print statements appear from the `dp_change_handler` callback.
#
# # Other notes
#
# The cell that created the datepicker above deserves additional explanation.
#
# * `._null()` at the end of a chain of proxy commands indicates that the result of the command should be discarded.
# The result for that command sent back to Python will be `None`.  This is useful to prevent communication of
# large datastructures that are not needed.
#
# * The `dp.window()` proxy command corresponds to the browser window namespace.
# This allows the proxy widget access to global names in the browser environment such
# as `dp.window().jQuery` which identifies the jQuery object.
#
# * The `data` given to the proxy callback may be used to for cross referencing events
# with other data structures (without having to define a new callback for every event).
#
# * The `proxy_callback` is set to translate JSON values 3 levels deep because the
# arguments sent to the callback from javascript holds the changed input value
# `arguments['0']['target']['value']`, which is 3 levels deep.
#
# * Callbacks functions registered using `w.callback(callback_function)` are stored
# forever in an internal data structure `w.identifier_to_callback` unless the
# the callback function is explicitly deleted with `w.forget_callback(callback_function)`.
#
# * In the code we use `dp.window().JQuery("#dp000")` multiple times for simplicity.  It is also
# possible to use a variable `dp000 = dp.window().JQuery("#dp000")` as a shorthand.
#
# # Storing javascript values in the "element"
#
# It is often important to store data structures created in Javascript for later
# use.  Any javascript value which can be identified or created by the proxy mechanism
# can be stored into the `element` object using the `_set` method.  For example the following interaction
# creates a new `input` element and stores it in the `element` object namespace.

# %%
document = dp.window().document
new_input = document.createElement("input")
save_input = dp.element()._set("saved_input", new_input)
dp.send(save_input)
# Out:
# [2,
#  [['set',
#    ['element'],
#    'saved_input',
#    ['method', ['get', ['window'], 'document'], 'createElement', 'input']]],
#  1]

# %%
# what is the type of the new input element?
dp.send(dp.element().saved_input.type)
# Out:
# [3, [['get', ['get', ['element'], 'saved_input'], 'type']], 1]

# %%
# apparently the default type for an input element is "text"
dp.results
# Out:
# [3, [u'text']]
